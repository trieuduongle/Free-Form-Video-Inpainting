# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/trieuduongle/Free-Form-Video-Inpainting.git '/content/drive/My Drive/Duong/Free-Form-Video-Inpainting'
# Out:
# Cloning into '/content/drive/My Drive/Duong/Free-Form-Video-Inpainting'...
# remote: Enumerating objects: 348, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 348 (delta 33), reused 30 (delta 28), pack-reused 285
# Receiving objects: 100% (348/348), 40.30 MiB | 18.25 MiB/s, done.
# Resolving deltas: 100% (72/72), done.
# Checking out files: 100% (227/227), done.

# %%
# %cd '/content/drive/My Drive/Duong/Free-Form-Video-Inpainting'
# Out:
# /content/drive/My Drive/Duong/Free-Form-Video-Inpainting

# %%
# !git fetch origin && git checkout colab && git pull
# Out:
# M	doc/gif_teaser.gif
# M	doc/gif_teaser2.gif
# M	doc/gif_teaser3.gif
# M	libs/PerceptualSimilarity/models/__init__.py
# M	libs/PerceptualSimilarity/models/base_model.py
# M	libs/PerceptualSimilarity/models/dist_model.py
# M	libs/PerceptualSimilarity/models/models.py
# M	libs/PerceptualSimilarity/models/networks_basic.py
# M	libs/PerceptualSimilarity/util/html.py
# M	libs/PerceptualSimilarity/util/visualizer.py
# M	libs/video_quality/vifp.py
# M	paper/camera_ready.pdf
# M	paper/camera_ready_sup.pdf
# Branch 'colab' set up to track remote branch 'colab' from 'origin'.
# Switched to a new branch 'colab'
# Already up to date.

# %%
# !unzip '/content/drive/My Drive/Duong/datasets/FVI.zip.zip' -d '/content/drive/My Drive/Duong/datasets/FVI'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/My Drive/Duong/datasets/FVI/FVI/Test/random_masks/rand_curve_noBoarder/35/rand_curve_noBoarder_35_069/mask_0026.png
#  extracting: /content/drive/My Drive/Duong/datasets/FVI/FVI/Test/random_masks/rand_curve_noBoarder/35/rand_curve_noBoarder_35_069/mask_0019.png
#  extracting: /content/drive/My Drive/Duong/datasets/FVI/FVI/Test/random_masks/rand_curve_noBoarder/35/rand_curve_noBoarder_35_069/mask_0022.png
#  extracting: /content/drive/My Drive/Duong/datasets/FVI/FVI/Test/random_masks/rand_curve_noBoarder/35/rand_curve_noBoarder_35_069/mask_0010.png
#  extracting: /content/drive/My Drive/Duong/datasets/FVI/FVI/Test/random_masks/rand_curve_noBoarder/35/rand_curve_noBoarder_35_069/mask_0008.png
#  extracting: /content/drive/My Drive/Duong/datasets/FVI/FVI/Test/random_masks/rand_curve_noBoarder/35/rand_curve_noBoarder_35_069/mask_0025.png
# ...

# %%
# !git pull && pip install -r requirements.txt
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/trieuduongle/Free-Form-Video-Inpainting
#    48e67c0..486b8ae  colab      -> origin/colab
# Updating 48e67c0..486b8ae
# Fast-forward
#  src/dataset_configs/FVI_all_masks.json | 12 ++++++------
#  1 file changed, 6 insertions(+), 6 deletions(-)

# %%
# !cd src && python train.py --config config.json --dataset_config dataset_configs/FVI_all_masks.json
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [2022-12-27 17:11:58] {train.py:122} INFO - Overriding "data_loader" of config by given dataset_config
# [2022-12-27 17:11:58] {train.py:122} INFO - Overriding "test_data_loader" of config by given dataset_config
# [2022-12-27 17:12:14] {util.py:66} INFO - Reading directories under /content/drive/My Drive/Duong/datasets/FVI/Train/JPEGImages/, exclude [], num: 1940
# ...

# %%
from skimage.metrics import structural_similarity
